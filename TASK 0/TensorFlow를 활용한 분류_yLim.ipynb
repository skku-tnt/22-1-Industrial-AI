# %% [markdown]
# # 사물 이미지 분류 경진대회 Baseline1
#
# 이번 대회는 주어진 이미지의 종류를 분류하는 대회입니다.
#
# 단순 이미지 분류 문제이지만 이미지 처리를 처음 시작하시는 분들은 아마도 막막하실 겁니다.
#
# 따라서 간단한 CNN 모델로 자동차, 말, 새 등 10가지 카테고리의 중 이미지들을 올바른 라벨로 분류하는 코드를 제공해드립니다.
#
# 베이스라인을 통해 이미지 처리 기초에 입문해보세요!

# %% [markdown]
# ### 설명

# %% [markdown]
# ## Convolutional Neural Network(CNN)
#
# 코드로 들어가기 전 먼저 간단하게 CNN 모델을 이해하기 위한 기본 개념들을 둘러보겠습니다.
#
# ### Neural Network
#
# 인공지능에서 기본 개념으로 사용되는 인공신경망 뉴런은 생물학적 뉴런을 수학적으로 모델링한 것입니다.
#
# 인공신경망 뉴런은 여러 입력값을 받아 일정 수준을 넘어서게 되면 활성화되고 출력값을 내보냅니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Neural_network.svg/1200px-Neural_network.svg.png?20210102213114" alt="neuralnetwork_image" height="700" width="600"/>
#
# [이미지 출처](https://commons.wikimedia.org/wiki/File:Neural_network.svg)
#
# #### Sigmoid
#
# 여기서 사용되는 함수가 바로 "Sigmoid"입니다.
#
# sigmoid 함수는 활성화 함수(Activation function)로 많이 사용되며 보통 0.5 미만은 0, 이상은 1을 출력하게 됩니다.
#
# #### sigmoid(x) = 1 / 1 + exp(-x)
#
# 그래프는 다음과 같습니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/53/Sigmoid-function-2.svg/1600px-Sigmoid-function-2.svg.png?20160528050132" alt="sigmoid_image" height="700" width="600"/>
#
# [이미지 출처](https://commons.wikimedia.org/wiki/File:Sigmoid-function-2.svg)
#
# 그러나 이런 sigmoid 함수에는 단점이 있습니다.
#
# 그래프를 보시면 양 극단 값의 기울기(미분값)이 0에 가까워져 학습이 되지 않는 문제가 발생합니다. 이를 Gradient Vanishing 문제라고 하는데 이러한 문제를 해결하기 위해 다양한 활성화 함수들이 고안되었습니다.
#
# #### ReLU
#
# ReLU 함수는 그렇게 고안된 활성화 함수 중 하나로, Gradient Vanishing 문제를 해결 가능합니다.
#
# #### relu(x) = 0 if x < 0 else max(0,x)
#
# 위 식과 같이 ReLU 함수는 입력값을 0과 비교해 둘 중 큰 값을 출력합니다.
#
# 따라서 계산이 빠르고 양 극단값이 포화되지 않는다는 장점이 있습니다.
#
# 그러나 여전히 음수인 경우에는 0을 출력하여 학습이 이루어지지 않는다는 단점이 존재합니다.
#
# <img src="https://www.researchgate.net/publication/340644173/figure/fig3/AS:880423093673984@1586920631034/4a-Graph-of-the-ReLU-function-4b-Graph-of-gradient-of-ReLU-function.ppm" alt="relu_image" height="700" width="600"/>
#
# ### Perceptron
#
# 퍼셉트론이란 신경망의 기원이 되는 개념으로, Frank Rosenblatt이 1957년 고안한 알고리즘입니다.
#
# 이는 여러 신호를 입력받아 0(흐르지 않는다) 또는 1(흐른다)이라는 출력값을 앞으로 전달합니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Perceptron-unit.svg/1278px-Perceptron-unit.svg.png?20160606160836" alt="preceptron_image" height="700" width="600"/>
#
# [이미지 출처](https://commons.wikimedia.org/wiki/File:Perceptron-unit.svg)
#
#
# 각 입력 신호 X는 각 가중치 w와 곱해집니다. 가중치가 클수록 그 신호가 중요하다는 뜻입니다.
#
# 그러나 퍼셉트론은 단순한 선형 분류기로, AND나 OR과 같은 분류는 가능하나 XOR 분류는 불가능합니다.
#
#
# ### MLP(Multi-Layer Perceptron)
#
# 직선형 영역만 표시할 수 있는 단층 퍼셉트론의 한계를 극복하기 위해 고안된 것이 다층 퍼셉트론입니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/28/MultiLayerPerceptron.png?20120416020124" alt="preceptron_image" height="700" width="600"/>
#
# [이미지 출처](https://commons.wikimedia.org/wiki/File:MultiLayerPerceptron.png)
#
# XOR 문제의 경우 각 영역을 직선으로 분리가 불가능한데, 비선형 영역까지 표현 가능한 다층 퍼셉트론으로 XOR 게이트까지 구현할 수 있습니다.
#
# 더 자세한 내용이 궁금하다면 [여기](https://brunch.co.kr/@gdhan/6)를 참고하세요!

# %% [markdown]
# ## 환경 설정 및 데이터 로드
#
# 이제 분석할 데이터를 작업장으로 가져오겠습니다.

# %%
import os
import warnings
warnings.filterwarnings(action='ignore')

os.environ["CUDA_VISIBLE_DEVICES"]="0" # GPU 할당

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#create training dataset
from glob import glob
import numpy as np
import PIL
from PIL import Image
import tensorflow as tf
from tensorflow import keras

# path = './data/train/'

# training_images = []
# training_labels = []

# for filename in glob(path +"*"):
#     for img in glob(filename + "/*.jpg"):
#         an_img = PIL.Image.open(img) #read img
#         img_array = np.array(an_img) #img to array
#         training_images.append(img_array) #append array to training_images 
#         label = filename.split('/')[3] #get label
#         training_labels.append(label) #append label
        
# training_images = np.array(training_images)
# training_labels = np.array(training_labels)

# from sklearn.preprocessing import LabelEncoder

# le = LabelEncoder()
# training_labels= le.fit_transform(training_labels)
# training_labels = training_labels.reshape(-1,1)

# print(training_images.shape)
# print(training_labels.shape)

# %%
#create training dataset
from glob import glob
import numpy as np
import PIL
from PIL import Image
import tensorflow as tf


path = './data/train/'

training_images = []
training_labels = []

for filename in glob(path +"*"):
    for img in glob(filename + "/*.jpg"):
        an_img = PIL.Image.open(img) #read img
        img_array = np.array(an_img) #img to array
        training_images.append(img_array) #append array to training_images 
        label = filename.split('/')[3] #get label
        training_labels.append(label) #append label
        
training_images = np.array(training_images)
training_labels = np.array(training_labels)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
training_labels= le.fit_transform(training_labels)
training_labels = training_labels.reshape(-1,1)

print(training_images.shape)
print(training_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
(training_images, training_labels), (test_images, test_idx) = keras.datasets.cifar10.load_data()
assert training_images.shape == (50000, 32, 32, 3)
assert test_images.shape == (10000, 32, 32, 3)
assert training_labels.shape == (50000, 1)
assert test_idx.shape == (10000, 1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
#create test dataset

path = './data/test/'

test_images = []
test_idx = []

flist = sorted(glob(path + '*.jpg'))

for filename in flist:
    an_img = PIL.Image.open(filename) #read img
    img_array = np.array(an_img) #img to array
    test_images.append(img_array) #append array to training_images 
    
    label = filename.split('/')[3] #get id 
    test_idx.append(label) #append id
    
test_images = np.array(test_images)

print(test_images.shape)
print(test_idx[0:5])
# Out:
# (10000, 32, 32, 3)
# ['0000.jpg', '0001.jpg', '0002.jpg', '0003.jpg', '0004.jpg']

# %%
print(test_idx[0:5])
# Out:
# [[3]
#  [8]
#  [8]
#  [0]
#  [6]]

# %% [markdown]
# 불러온 데이터셋을 살펴보겠습니다.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(training_images[i])
    print(training_labels[i], end=",")
plt.show()
# Out:
# [6],[9],[9],[4],[1],[1],[2],[7],[8],[3],

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(training_images[i])
    print(training_labels[i], end=",")
plt.show()
# Out:
# [2],[2],[2],[2],[2],[2],[2],[2],[2],[2],

# %% [markdown]
# 이미지를 살펴보면 10가지 종류의 이미지들이 존재하며 0부터 9까지 10개의 라벨이 달려있습니다.
#
# CIFAR-10 이미지 데이터셋을 분류하기 위해 CNN의 기본 개념을 이해하고 데이터셋에 적용해보도록 하겠습니다.
#
# 우리의 목표는 CNN 모델을 통해 10가지 종류의 이미지들을 각 레이블에 맞게 분류하는 것입니다.

# %% [markdown]
# ## 데이터셋 준비
# 데이터셋을 X와 y로 분리하고, train 이미지 데이터셋을 학습용과 검증용으로 나누어줍니다.

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(training_images, training_labels, test_size=0.2, random_state=42)

X_test = test_images

# %%
print('X_train 크기:',X_train.shape)
print('X_valid 크기:',X_valid.shape)
print('X_test  크기:',X_test.shape)
# Out:
# X_train 크기: (40000, 32, 32, 3)
# X_valid 크기: (10000, 32, 32, 3)
# X_test  크기: (10000, 32, 32, 3)

# %% [markdown]
# 이미지의 RGB 채널은 각각 0~255까지의 값을 갖고 있기 때문에
#
# 255로 나누어 0에서 1 사이 값을 갖도록 normalization을 해줍니다.

# %%
X_train = X_train / 255.0
X_valid = X_valid / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## CNN 모델 설계
#
# 필요한 layer들을 추가하며 CNN 모델을 설계합니다.
#
# 자세한 내용은 뒤에 이어서 설명하겠습니다.

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding='SAME',input_shape=(32, 32, 3)), #cnn layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2, padding='SAME'), #pooling layer
    tf.keras.layers.Dropout(0.23), # 무작위로 퍼셉트론 비활성화(23%)
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='SAME'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2, padding='SAME'),
    tf.keras.layers.Dropout(0.23),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='SAME'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2, padding='SAME'),
    tf.keras.layers.Dropout(0.23),
    tf.keras.layers.Flatten(), # N차원 배열 -> 1차원 배열
    tf.keras.layers.Dense(2048, activation = 'relu'), #fully connected layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation = 'softmax') # ouput layer
])

# %% [markdown]
# 이제 위 모델에서 사용한 각 Layer들에 대해 살펴보겠습니다.
#
# ### Convoultion Layer
#
# Convolution Layer에서는 이미지의 특징(feature map)을 추출해내는 역할을 합니다.
#
# 입력 데이터가 주어지면 필터를 이용해 특징을 추출한 다음 아웃풋을 내보냅니다.
#
# 이 필터는 커널(Kernel) 혹은 가중치의 배열이라고도 부르며 이 값을 조정하는 것이 곧 학습을 의미합니다.
#
# 첫번째 Convolution Layer에서는 3x3 크기의 커널을 사용했습니다. 이는 곧 학습해야 할 가중치가 9개라는 뜻입니다.
#
# * Stride
#
# 커널을 이동시키는 거리입니다. 특별한 언급이 없다면 1로 가정합니다.
#
# Convolution을 하게되면 입력 데이터의 크기가 자연스럽게 줄어들게 되는데, 주변에 값이 0인 셀들을 추가(Padding)해서 입력 데이터의 크기를 유지시키기도 합니다.
#
# [참고](https://hdevstudy.tistory.com/116)
#
# * Padding
#
# zero padding은 이미지 주위에 0을 둘러서 이미지 데이터의 축소를 방지해주는 역할을 합니다.
#
# 필터로 인해 특징이 추출되면 자연스럽게 크기가 작아지는데, 이미지 벡터들 가장자리에 0을 채워 Convolution Layer를 통과할 때 크기를 동일하게 유지시켜줄 수 있습니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/2d/Convolution_arithmetic_-_Padding_strides_odd.gif" />
#
# ### Pooling Layer - Max Pooling
#
# Pooling Layer는 데이터의 공간적 크기를 축소하는데 사용합니다.
#
# 보통 이 레이어에서 이미지의 크기를 조절하며, CNN에서는 주로 Max-Pooling 방식을 사용합니다.
#
# Conv layer 는 이미지의 특정 영역의 특징을 잡아내는 역할이라면, Pooling 은 이미지의 크기를 줄이는 동시에 이미지의 전체의 특징 또한 보존합니다.
#
# 따라서 Pooling 은 모델로 하여금 이미지 전체를 볼 수 있게 도와줍니다.
#
# Max Pooling에서는 선택된 영역에서 가장 큰 값을 뽑아 대표값으로 설정하는 방식입니다.
#
# 이를 통해 학습 시간을 단축하고 오버피팅 문제를 완화할 수 있습니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e9/Max_pooling.png?20151216202132" />
#
#
# ### Dropout
#
# Drop Out 방식은 뉴럴 네트워크의 유닛(뉴런)들을 랜덤으로 비활성화 하여 과적합(Overfittng)을 방지하기 위한 기법입니다.
#
# ### Fully Connected Layer
#
# *  Flatten Layer
#
# N차원 배열을 1차원으로 변환합니다.
#
# * Dense Layer
#
# 1차원 배열을 뉴럴넷에 입력해 줍니다.
#
# 이때, Dense Layer 는 오로지 퍼셉트론이로 이루어진 layer 입니다.
#
#
# * Softmax
#
# Softmax는 활성화 함수의 일종이며 마지막 layer 에서 class 별 확률를 출력하기 위해 사용됩니다.

# %%
model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# * Loss Functinon (손실 함수)
#
# 이때 Loss Function 은 실재 값과 모델이 예측한 값의 거리를 출력하는 함수 입니다.
#
# 쉽게 말해 Loss Function 은 모델의 예측이 얼마나 틀렸는지를 알려주는 함수 입니다.
#
# 이 때 "모델의 예측이 얼마나 틀렸는지" 를 어떻게 정의하느냐에 따라 어떤 Loss Function 을 사용할 지가 정해집니다.
#
# ----
#
# 이번 베이스라인에서는 최적화 함수로는 Adam 함수를 사용했고, 손실함수로는 'sparse_categorical_crossentropy', 그리고 평가지표로는 정확도를 사용했습니다.
#
# 모델을 완성했으면 summary() 함수를 통해 모델의 세부 내용를 요약 출력해봅니다.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        448
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        4640
#
#  batch_normalization (BatchN  (None, 16, 16, 32)       128
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  dropout_5 (Dropout)         (None, 8, 8, 32)          0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 32)          0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 2048)              1050624
#
#  dropout_7 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 1,085,578
# Trainable params: 1,085,514
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# ## 학습
# ### batch size
#
# batch size란 cpu 또는 gpu 연산 시, 하드웨어로 로드되는 데이터의 개수 입니다.
#
# 본인의 컴퓨팅 환경에 따라 batch size 를 조절하는 것이 좋습니다.
#
# gpu 를 사용하는 경우 본인의 gpu 메모리 용량을 고려하여 batch size 를 설정해 주어야 합니다.
#
# batch size 는 모델 학습 과정에 영향을 끼치기도 합니다.
#
# 따라서 하드웨어 상황을 고려하면서도 학습 과정 또한 고려하여 batch size 를 설정해 주어야 합니다.
#
# ### epoch
#
# 딥러닝에서 epoch는 전체 트레이닝 셋이 신경망을 통과한 횟수입니다.
#
# 1-epoch는 전체 트레이닝 셋이 하나의 신경망에 적용되어 순전파와 역전파를 통해 신경망을 한 번 통과했다는 뜻입니다.
#
# epoch 은 많을 수록 학습이 잘되는 것이 아닙니다.
#
# epoch 이 너무 적을 경우 학습이 덜 이루어지는 경우가 있고, epoch 이 너무 많을 경우 과적합이 되는 경우가 있습니다.
#
# 따라서 적절한 epoch 을 설정해 주어야 합니다.
#
# 이때 validation loss 와 accuracy 은 epoch 을 언제 중단 할지 모니터링 하는 용도로 사용되기도 합니다.
#
# 자, 이제 CNN 모델 설계를 완료했으니 다음과 같이 배치 사이즈와 에폭을 설정하여 모델을 학습시키겠습니다.

# %%
history = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=350, batch_size=128)
# Out:
# Epoch 1/350
# 313/313 [==============================] - 12s 7ms/step - loss: 2.0753 - accuracy: 0.3762 - val_loss: 4.1082 - val_accuracy: 0.1151
# Epoch 2/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.5201 - accuracy: 0.4785 - val_loss: 1.5109 - val_accuracy: 0.4814
# Epoch 3/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.3403 - accuracy: 0.5264 - val_loss: 1.2756 - val_accuracy: 0.5596
# Epoch 4/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.2369 - accuracy: 0.5645 - val_loss: 1.2267 - val_accuracy: 0.5811
# Epoch 5/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.1619 - accuracy: 0.5921 - val_loss: 1.2316 - val_accuracy: 0.6109
# Epoch 6/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0975 - accuracy: 0.6134 - val_loss: 1.3387 - val_accuracy: 0.5844
# Epoch 7/350
# 313/313 [==============================] - 2s 6ms/step - loss: 1.0561 - accuracy: 0.6277 - val_loss: 1.2640 - val_accuracy: 0.6007
# Epoch 8/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9935 - accuracy: 0.6508 - val_loss: 0.9595 - val_accuracy: 0.6798
# Epoch 9/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9407 - accuracy: 0.6705 - val_loss: 0.8596 - val_accuracy: 0.7001
# Epoch 10/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9173 - accuracy: 0.6784 - val_loss: 0.8448 - val_accuracy: 0.7068
# Epoch 11/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.8832 - accuracy: 0.6907 - val_loss: 0.9374 - val_accuracy: 0.6908
# Epoch 12/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.8623 - accuracy: 0.6973 - val_loss: 0.9400 - val_accuracy: 0.6838
# Epoch 13/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.8359 - accuracy: 0.7028 - val_loss: 1.1327 - val_accuracy: 0.6348
# Epoch 14/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.8138 - accuracy: 0.7142 - val_loss: 0.7974 - val_accuracy: 0.7303
# Epoch 15/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7983 - accuracy: 0.7214 - val_loss: 0.8476 - val_accuracy: 0.7150
# Epoch 16/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7722 - accuracy: 0.7284 - val_loss: 0.7674 - val_accuracy: 0.7351
# Epoch 17/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7558 - accuracy: 0.7344 - val_loss: 0.9032 - val_accuracy: 0.7001
# Epoch 18/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7436 - accuracy: 0.7385 - val_loss: 0.9992 - val_accuracy: 0.6887
# Epoch 19/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7212 - accuracy: 0.7461 - val_loss: 0.8031 - val_accuracy: 0.7327
# Epoch 20/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7103 - accuracy: 0.7475 - val_loss: 0.8458 - val_accuracy: 0.7256
# Epoch 21/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7011 - accuracy: 0.7531 - val_loss: 0.7780 - val_accuracy: 0.7394
# Epoch 22/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6890 - accuracy: 0.7564 - val_loss: 1.1569 - val_accuracy: 0.6683
# Epoch 23/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6688 - accuracy: 0.7630 - val_loss: 0.7860 - val_accuracy: 0.7417
# Epoch 24/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6620 - accuracy: 0.7649 - val_loss: 1.0107 - val_accuracy: 0.6815
# Epoch 25/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6462 - accuracy: 0.7712 - val_loss: 0.7202 - val_accuracy: 0.7580
# Epoch 26/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6390 - accuracy: 0.7750 - val_loss: 0.7186 - val_accuracy: 0.7524
# Epoch 27/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6320 - accuracy: 0.7796 - val_loss: 0.8332 - val_accuracy: 0.7372
# Epoch 28/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6181 - accuracy: 0.7810 - val_loss: 0.7585 - val_accuracy: 0.7514
# Epoch 29/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6105 - accuracy: 0.7865 - val_loss: 0.7872 - val_accuracy: 0.7456
# Epoch 30/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5962 - accuracy: 0.7886 - val_loss: 0.9908 - val_accuracy: 0.6932
# Epoch 31/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5809 - accuracy: 0.7936 - val_loss: 0.7421 - val_accuracy: 0.7570
# Epoch 32/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5810 - accuracy: 0.7954 - val_loss: 1.0295 - val_accuracy: 0.7067
# Epoch 33/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5799 - accuracy: 0.7957 - val_loss: 0.8875 - val_accuracy: 0.7230
# Epoch 34/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5634 - accuracy: 0.7993 - val_loss: 0.8437 - val_accuracy: 0.7320
# Epoch 35/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5552 - accuracy: 0.8043 - val_loss: 0.7562 - val_accuracy: 0.7594
# Epoch 36/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5484 - accuracy: 0.8060 - val_loss: 0.7029 - val_accuracy: 0.7686
# Epoch 37/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5426 - accuracy: 0.8080 - val_loss: 0.9473 - val_accuracy: 0.7131
# Epoch 38/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5315 - accuracy: 0.8104 - val_loss: 0.6997 - val_accuracy: 0.7706
# Epoch 39/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5296 - accuracy: 0.8162 - val_loss: 0.8745 - val_accuracy: 0.7309
# Epoch 40/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5189 - accuracy: 0.8166 - val_loss: 0.7438 - val_accuracy: 0.7593
# Epoch 41/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5178 - accuracy: 0.8166 - val_loss: 0.7601 - val_accuracy: 0.7604
# Epoch 42/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5186 - accuracy: 0.8173 - val_loss: 0.7163 - val_accuracy: 0.7682
# Epoch 43/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5142 - accuracy: 0.8198 - val_loss: 0.7198 - val_accuracy: 0.7663
# Epoch 44/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5028 - accuracy: 0.8229 - val_loss: 0.6749 - val_accuracy: 0.7839
# Epoch 45/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4965 - accuracy: 0.8265 - val_loss: 0.6753 - val_accuracy: 0.7824
# Epoch 46/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4885 - accuracy: 0.8266 - val_loss: 0.6933 - val_accuracy: 0.7764
# Epoch 47/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4877 - accuracy: 0.8263 - val_loss: 0.7579 - val_accuracy: 0.7558
# Epoch 48/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4790 - accuracy: 0.8302 - val_loss: 0.8239 - val_accuracy: 0.7500
# Epoch 49/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4747 - accuracy: 0.8317 - val_loss: 0.6856 - val_accuracy: 0.7804
# Epoch 50/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4707 - accuracy: 0.8321 - val_loss: 0.6599 - val_accuracy: 0.7862
# Epoch 51/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4732 - accuracy: 0.8350 - val_loss: 0.8262 - val_accuracy: 0.7489
# Epoch 52/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4600 - accuracy: 0.8382 - val_loss: 0.7300 - val_accuracy: 0.7663
# Epoch 53/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4617 - accuracy: 0.8369 - val_loss: 0.8269 - val_accuracy: 0.7420
# Epoch 54/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4555 - accuracy: 0.8384 - val_loss: 0.6778 - val_accuracy: 0.7843
# Epoch 55/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4496 - accuracy: 0.8410 - val_loss: 0.7207 - val_accuracy: 0.7766
# Epoch 56/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4457 - accuracy: 0.8429 - val_loss: 0.7758 - val_accuracy: 0.7563
# Epoch 57/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4466 - accuracy: 0.8413 - val_loss: 0.6691 - val_accuracy: 0.7842
# Epoch 58/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4424 - accuracy: 0.8422 - val_loss: 0.8330 - val_accuracy: 0.7504
# Epoch 59/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4325 - accuracy: 0.8475 - val_loss: 0.7985 - val_accuracy: 0.7587
# Epoch 60/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4188 - accuracy: 0.8512 - val_loss: 0.7298 - val_accuracy: 0.7745
# Epoch 61/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4315 - accuracy: 0.8463 - val_loss: 0.7527 - val_accuracy: 0.7682
# Epoch 62/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4211 - accuracy: 0.8512 - val_loss: 0.6960 - val_accuracy: 0.7844
# Epoch 63/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4251 - accuracy: 0.8508 - val_loss: 0.6504 - val_accuracy: 0.7897
# Epoch 64/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4185 - accuracy: 0.8507 - val_loss: 0.7268 - val_accuracy: 0.7699
# Epoch 65/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4130 - accuracy: 0.8544 - val_loss: 0.7963 - val_accuracy: 0.7591
# Epoch 66/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4176 - accuracy: 0.8519 - val_loss: 0.7412 - val_accuracy: 0.7759
# Epoch 67/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4157 - accuracy: 0.8531 - val_loss: 0.7795 - val_accuracy: 0.7612
# Epoch 68/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3968 - accuracy: 0.8591 - val_loss: 0.6773 - val_accuracy: 0.7877
# Epoch 69/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4006 - accuracy: 0.8589 - val_loss: 0.7481 - val_accuracy: 0.7635
# Epoch 70/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4033 - accuracy: 0.8574 - val_loss: 0.7160 - val_accuracy: 0.7786
# Epoch 71/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3973 - accuracy: 0.8593 - val_loss: 0.6926 - val_accuracy: 0.7870
# Epoch 72/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3900 - accuracy: 0.8632 - val_loss: 0.7886 - val_accuracy: 0.7625
# Epoch 73/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3917 - accuracy: 0.8632 - val_loss: 0.9333 - val_accuracy: 0.7351
# Epoch 74/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3822 - accuracy: 0.8664 - val_loss: 0.7309 - val_accuracy: 0.7782
# Epoch 75/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3763 - accuracy: 0.8669 - val_loss: 0.8475 - val_accuracy: 0.7477
# Epoch 76/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3886 - accuracy: 0.8630 - val_loss: 0.7070 - val_accuracy: 0.7872
# Epoch 77/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3799 - accuracy: 0.8638 - val_loss: 0.7372 - val_accuracy: 0.7734
# Epoch 78/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3859 - accuracy: 0.8640 - val_loss: 0.7401 - val_accuracy: 0.7752
# Epoch 79/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3737 - accuracy: 0.8683 - val_loss: 0.6971 - val_accuracy: 0.7940
# Epoch 80/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3651 - accuracy: 0.8723 - val_loss: 0.7444 - val_accuracy: 0.7749
# Epoch 81/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3779 - accuracy: 0.8670 - val_loss: 0.7112 - val_accuracy: 0.7839
# Epoch 82/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3679 - accuracy: 0.8694 - val_loss: 0.6837 - val_accuracy: 0.7912
# Epoch 83/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3622 - accuracy: 0.8698 - val_loss: 0.6631 - val_accuracy: 0.7943
# Epoch 84/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3727 - accuracy: 0.8695 - val_loss: 0.6905 - val_accuracy: 0.7927
# Epoch 85/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3629 - accuracy: 0.8751 - val_loss: 0.7107 - val_accuracy: 0.7835
# Epoch 86/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3652 - accuracy: 0.8730 - val_loss: 0.6893 - val_accuracy: 0.7894
# Epoch 87/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3587 - accuracy: 0.8735 - val_loss: 0.7115 - val_accuracy: 0.7837
# Epoch 88/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3519 - accuracy: 0.8768 - val_loss: 0.7347 - val_accuracy: 0.7686
# Epoch 89/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3582 - accuracy: 0.8729 - val_loss: 0.7041 - val_accuracy: 0.7787
# Epoch 90/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3552 - accuracy: 0.8739 - val_loss: 0.7046 - val_accuracy: 0.7887
# Epoch 91/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3502 - accuracy: 0.8747 - val_loss: 0.7606 - val_accuracy: 0.7610
# Epoch 92/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3562 - accuracy: 0.8741 - val_loss: 0.7506 - val_accuracy: 0.7792
# Epoch 93/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3493 - accuracy: 0.8775 - val_loss: 0.8277 - val_accuracy: 0.7610
# Epoch 94/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3433 - accuracy: 0.8781 - val_loss: 0.7321 - val_accuracy: 0.7799
# Epoch 95/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3458 - accuracy: 0.8798 - val_loss: 0.7263 - val_accuracy: 0.7841
# Epoch 96/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3511 - accuracy: 0.8780 - val_loss: 0.8689 - val_accuracy: 0.7474
# Epoch 97/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3380 - accuracy: 0.8802 - val_loss: 0.7702 - val_accuracy: 0.7758
# Epoch 98/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3397 - accuracy: 0.8785 - val_loss: 0.7080 - val_accuracy: 0.7851
# Epoch 99/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3375 - accuracy: 0.8805 - val_loss: 0.6904 - val_accuracy: 0.7869
# Epoch 100/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3308 - accuracy: 0.8839 - val_loss: 0.8082 - val_accuracy: 0.7671
# Epoch 101/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3252 - accuracy: 0.8838 - val_loss: 0.6973 - val_accuracy: 0.7907
# Epoch 102/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3387 - accuracy: 0.8812 - val_loss: 0.7308 - val_accuracy: 0.7798
# Epoch 103/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3307 - accuracy: 0.8833 - val_loss: 0.7356 - val_accuracy: 0.7850
# Epoch 104/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3323 - accuracy: 0.8820 - val_loss: 0.7276 - val_accuracy: 0.7816
# Epoch 105/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3306 - accuracy: 0.8840 - val_loss: 0.7596 - val_accuracy: 0.7751
# Epoch 106/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3261 - accuracy: 0.8866 - val_loss: 0.7532 - val_accuracy: 0.7777
# Epoch 107/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3270 - accuracy: 0.8853 - val_loss: 0.7534 - val_accuracy: 0.7722
# Epoch 108/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3279 - accuracy: 0.8838 - val_loss: 0.7396 - val_accuracy: 0.7791
# Epoch 109/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3227 - accuracy: 0.8858 - val_loss: 0.7087 - val_accuracy: 0.7876
# Epoch 110/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3258 - accuracy: 0.8859 - val_loss: 0.7062 - val_accuracy: 0.7930
# Epoch 111/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3224 - accuracy: 0.8863 - val_loss: 0.7811 - val_accuracy: 0.7664
# Epoch 112/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3128 - accuracy: 0.8918 - val_loss: 0.7217 - val_accuracy: 0.7865
# Epoch 113/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3204 - accuracy: 0.8874 - val_loss: 0.7344 - val_accuracy: 0.7839
# Epoch 114/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3157 - accuracy: 0.8897 - val_loss: 0.7820 - val_accuracy: 0.7677
# Epoch 115/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3145 - accuracy: 0.8891 - val_loss: 0.6744 - val_accuracy: 0.7889
# Epoch 116/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3131 - accuracy: 0.8905 - val_loss: 0.7435 - val_accuracy: 0.7802
# Epoch 117/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3143 - accuracy: 0.8905 - val_loss: 0.7151 - val_accuracy: 0.7821
# Epoch 118/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3184 - accuracy: 0.8904 - val_loss: 0.7142 - val_accuracy: 0.7883
# Epoch 119/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3099 - accuracy: 0.8899 - val_loss: 0.8232 - val_accuracy: 0.7642
# Epoch 120/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3091 - accuracy: 0.8927 - val_loss: 0.6804 - val_accuracy: 0.7966
# Epoch 121/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3109 - accuracy: 0.8906 - val_loss: 0.8081 - val_accuracy: 0.7730
# Epoch 122/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3101 - accuracy: 0.8907 - val_loss: 0.7277 - val_accuracy: 0.7878
# Epoch 123/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3027 - accuracy: 0.8945 - val_loss: 0.7024 - val_accuracy: 0.7906
# Epoch 124/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3079 - accuracy: 0.8921 - val_loss: 0.7023 - val_accuracy: 0.7875
# Epoch 125/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2997 - accuracy: 0.8946 - val_loss: 0.7294 - val_accuracy: 0.7808
# Epoch 126/350
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3022 - accuracy: 0.8939 - val_loss: 0.9770 - val_accuracy: 0.7283
# Epoch 127/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3016 - accuracy: 0.8942 - val_loss: 0.6800 - val_accuracy: 0.7952
# Epoch 128/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2940 - accuracy: 0.8969 - val_loss: 0.7601 - val_accuracy: 0.7869
# Epoch 129/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3000 - accuracy: 0.8946 - val_loss: 0.7448 - val_accuracy: 0.7832
# Epoch 130/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2952 - accuracy: 0.8964 - val_loss: 0.8653 - val_accuracy: 0.7638
# Epoch 131/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3057 - accuracy: 0.8953 - val_loss: 0.8081 - val_accuracy: 0.7681
# Epoch 132/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2998 - accuracy: 0.8950 - val_loss: 0.6644 - val_accuracy: 0.8026
# Epoch 133/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2946 - accuracy: 0.8957 - val_loss: 0.6732 - val_accuracy: 0.7993
# Epoch 134/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2920 - accuracy: 0.8984 - val_loss: 0.8332 - val_accuracy: 0.7650
# Epoch 135/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2898 - accuracy: 0.8995 - val_loss: 0.7353 - val_accuracy: 0.7841
# Epoch 136/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2960 - accuracy: 0.8957 - val_loss: 0.8898 - val_accuracy: 0.7531
# Epoch 137/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2920 - accuracy: 0.8985 - val_loss: 0.7882 - val_accuracy: 0.7758
# Epoch 138/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2996 - accuracy: 0.8959 - val_loss: 0.8387 - val_accuracy: 0.7612
# Epoch 139/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2860 - accuracy: 0.8981 - val_loss: 0.7459 - val_accuracy: 0.7786
# Epoch 140/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2859 - accuracy: 0.9000 - val_loss: 0.7385 - val_accuracy: 0.7830
# Epoch 141/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2850 - accuracy: 0.9017 - val_loss: 0.7235 - val_accuracy: 0.7942
# Epoch 142/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2856 - accuracy: 0.8968 - val_loss: 0.7075 - val_accuracy: 0.7940
# Epoch 143/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2810 - accuracy: 0.9009 - val_loss: 0.7590 - val_accuracy: 0.7742
# Epoch 144/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2834 - accuracy: 0.9020 - val_loss: 0.7475 - val_accuracy: 0.7836
# Epoch 145/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2835 - accuracy: 0.9011 - val_loss: 0.7723 - val_accuracy: 0.7879
# Epoch 146/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2870 - accuracy: 0.8996 - val_loss: 0.7200 - val_accuracy: 0.7963
# Epoch 147/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2783 - accuracy: 0.9030 - val_loss: 0.9268 - val_accuracy: 0.7435
# Epoch 148/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2837 - accuracy: 0.9011 - val_loss: 0.7923 - val_accuracy: 0.7753
# Epoch 149/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2743 - accuracy: 0.9041 - val_loss: 0.7301 - val_accuracy: 0.7948
# Epoch 150/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2768 - accuracy: 0.9039 - val_loss: 0.8275 - val_accuracy: 0.7678
# Epoch 151/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2768 - accuracy: 0.9026 - val_loss: 0.7135 - val_accuracy: 0.7960
# Epoch 152/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2787 - accuracy: 0.9039 - val_loss: 0.7028 - val_accuracy: 0.7957
# Epoch 153/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2806 - accuracy: 0.9006 - val_loss: 0.7393 - val_accuracy: 0.7911
# Epoch 154/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2737 - accuracy: 0.9042 - val_loss: 0.7707 - val_accuracy: 0.7808
# Epoch 155/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2700 - accuracy: 0.9065 - val_loss: 0.7390 - val_accuracy: 0.7869
# Epoch 156/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2735 - accuracy: 0.9051 - val_loss: 0.8093 - val_accuracy: 0.7718
# Epoch 157/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2660 - accuracy: 0.9067 - val_loss: 0.8822 - val_accuracy: 0.7596
# Epoch 158/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2735 - accuracy: 0.9048 - val_loss: 0.7373 - val_accuracy: 0.7930
# Epoch 159/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2696 - accuracy: 0.9058 - val_loss: 0.7953 - val_accuracy: 0.7777
# Epoch 160/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2729 - accuracy: 0.9044 - val_loss: 0.8739 - val_accuracy: 0.7554
# Epoch 161/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2804 - accuracy: 0.9024 - val_loss: 0.7254 - val_accuracy: 0.7909
# Epoch 162/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2693 - accuracy: 0.9050 - val_loss: 0.7014 - val_accuracy: 0.7953
# Epoch 163/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2675 - accuracy: 0.9049 - val_loss: 0.8334 - val_accuracy: 0.7623
# Epoch 164/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2669 - accuracy: 0.9058 - val_loss: 0.7340 - val_accuracy: 0.7931
# Epoch 165/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2619 - accuracy: 0.9082 - val_loss: 0.7023 - val_accuracy: 0.7977
# Epoch 166/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2694 - accuracy: 0.9068 - val_loss: 0.8113 - val_accuracy: 0.7717
# Epoch 167/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2655 - accuracy: 0.9077 - val_loss: 0.6922 - val_accuracy: 0.8017
# Epoch 168/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2710 - accuracy: 0.9050 - val_loss: 0.8259 - val_accuracy: 0.7634
# Epoch 169/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2652 - accuracy: 0.9076 - val_loss: 0.9059 - val_accuracy: 0.7501
# Epoch 170/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2678 - accuracy: 0.9067 - val_loss: 0.7076 - val_accuracy: 0.8005
# Epoch 171/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2608 - accuracy: 0.9121 - val_loss: 0.7958 - val_accuracy: 0.7773
# Epoch 172/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2592 - accuracy: 0.9099 - val_loss: 0.7596 - val_accuracy: 0.7767
# Epoch 173/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2624 - accuracy: 0.9091 - val_loss: 0.8097 - val_accuracy: 0.7615
# Epoch 174/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2563 - accuracy: 0.9108 - val_loss: 0.8696 - val_accuracy: 0.7662
# Epoch 175/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2578 - accuracy: 0.9096 - val_loss: 0.8508 - val_accuracy: 0.7658
# Epoch 176/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2613 - accuracy: 0.9078 - val_loss: 0.7615 - val_accuracy: 0.7817
# Epoch 177/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2602 - accuracy: 0.9086 - val_loss: 0.7843 - val_accuracy: 0.7788
# Epoch 178/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2591 - accuracy: 0.9098 - val_loss: 0.7349 - val_accuracy: 0.7899
# Epoch 179/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2594 - accuracy: 0.9109 - val_loss: 0.7088 - val_accuracy: 0.7968
# Epoch 180/350
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2607 - accuracy: 0.9094 - val_loss: 0.8561 - val_accuracy: 0.7581
# Epoch 181/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2613 - accuracy: 0.9080 - val_loss: 0.7931 - val_accuracy: 0.7758
# Epoch 182/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2503 - accuracy: 0.9111 - val_loss: 0.7277 - val_accuracy: 0.7906
# Epoch 183/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2517 - accuracy: 0.9136 - val_loss: 0.7926 - val_accuracy: 0.7777
# Epoch 184/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2589 - accuracy: 0.9096 - val_loss: 0.7904 - val_accuracy: 0.7785
# Epoch 185/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2551 - accuracy: 0.9117 - val_loss: 0.7325 - val_accuracy: 0.7977
# Epoch 186/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2575 - accuracy: 0.9102 - val_loss: 0.7312 - val_accuracy: 0.7934
# Epoch 187/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2520 - accuracy: 0.9123 - val_loss: 0.7570 - val_accuracy: 0.7860
# Epoch 188/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2512 - accuracy: 0.9119 - val_loss: 0.7831 - val_accuracy: 0.7891
# Epoch 189/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2484 - accuracy: 0.9124 - val_loss: 0.6922 - val_accuracy: 0.8046
# Epoch 190/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2554 - accuracy: 0.9132 - val_loss: 0.7424 - val_accuracy: 0.7935
# Epoch 191/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2515 - accuracy: 0.9125 - val_loss: 0.7577 - val_accuracy: 0.7895
# Epoch 192/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2474 - accuracy: 0.9128 - val_loss: 0.8544 - val_accuracy: 0.7684
# Epoch 193/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2502 - accuracy: 0.9133 - val_loss: 0.7166 - val_accuracy: 0.8038
# Epoch 194/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2451 - accuracy: 0.9141 - val_loss: 0.7163 - val_accuracy: 0.7997
# Epoch 195/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2445 - accuracy: 0.9153 - val_loss: 0.7732 - val_accuracy: 0.7787
# Epoch 196/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2455 - accuracy: 0.9119 - val_loss: 0.9236 - val_accuracy: 0.7523
# Epoch 197/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2543 - accuracy: 0.9123 - val_loss: 0.7333 - val_accuracy: 0.7952
# Epoch 198/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2439 - accuracy: 0.9163 - val_loss: 0.8982 - val_accuracy: 0.7599
# Epoch 199/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2405 - accuracy: 0.9158 - val_loss: 0.7564 - val_accuracy: 0.7868
# Epoch 200/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2516 - accuracy: 0.9130 - val_loss: 0.8071 - val_accuracy: 0.7761
# Epoch 201/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2430 - accuracy: 0.9151 - val_loss: 0.8043 - val_accuracy: 0.7751
# Epoch 202/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2455 - accuracy: 0.9143 - val_loss: 0.7728 - val_accuracy: 0.7779
# Epoch 203/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2405 - accuracy: 0.9157 - val_loss: 0.7505 - val_accuracy: 0.7929
# Epoch 204/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2403 - accuracy: 0.9162 - val_loss: 0.7294 - val_accuracy: 0.7977
# Epoch 205/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2476 - accuracy: 0.9149 - val_loss: 0.7877 - val_accuracy: 0.7826
# Epoch 206/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2379 - accuracy: 0.9174 - val_loss: 0.8763 - val_accuracy: 0.7628
# Epoch 207/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2504 - accuracy: 0.9142 - val_loss: 0.7910 - val_accuracy: 0.7887
# Epoch 208/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2403 - accuracy: 0.9179 - val_loss: 0.7074 - val_accuracy: 0.7966
# Epoch 209/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2452 - accuracy: 0.9147 - val_loss: 0.7140 - val_accuracy: 0.7965
# Epoch 210/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2393 - accuracy: 0.9175 - val_loss: 0.7354 - val_accuracy: 0.7906
# Epoch 211/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2433 - accuracy: 0.9150 - val_loss: 0.7244 - val_accuracy: 0.7983
# Epoch 212/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2409 - accuracy: 0.9160 - val_loss: 0.7858 - val_accuracy: 0.7808
# Epoch 213/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2428 - accuracy: 0.9161 - val_loss: 0.7364 - val_accuracy: 0.7919
# Epoch 214/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2385 - accuracy: 0.9165 - val_loss: 0.7129 - val_accuracy: 0.7890
# Epoch 215/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2365 - accuracy: 0.9170 - val_loss: 0.7860 - val_accuracy: 0.7788
# Epoch 216/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2362 - accuracy: 0.9182 - val_loss: 0.7131 - val_accuracy: 0.7956
# Epoch 217/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2365 - accuracy: 0.9182 - val_loss: 0.7445 - val_accuracy: 0.7917
# Epoch 218/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2355 - accuracy: 0.9192 - val_loss: 0.7917 - val_accuracy: 0.7786
# Epoch 219/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2404 - accuracy: 0.9172 - val_loss: 0.7404 - val_accuracy: 0.7968
# Epoch 220/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2354 - accuracy: 0.9172 - val_loss: 0.7385 - val_accuracy: 0.7907
# Epoch 221/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2392 - accuracy: 0.9161 - val_loss: 0.7069 - val_accuracy: 0.7990
# Epoch 222/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2328 - accuracy: 0.9192 - val_loss: 0.7805 - val_accuracy: 0.7871
# Epoch 223/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2405 - accuracy: 0.9175 - val_loss: 0.7828 - val_accuracy: 0.7878
# Epoch 224/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2362 - accuracy: 0.9185 - val_loss: 0.7225 - val_accuracy: 0.7961
# Epoch 225/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2321 - accuracy: 0.9190 - val_loss: 0.7561 - val_accuracy: 0.7943
# Epoch 226/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2372 - accuracy: 0.9168 - val_loss: 0.8244 - val_accuracy: 0.7724
# Epoch 227/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2285 - accuracy: 0.9210 - val_loss: 0.7882 - val_accuracy: 0.7799
# Epoch 228/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2324 - accuracy: 0.9200 - val_loss: 0.7448 - val_accuracy: 0.7950
# Epoch 229/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2368 - accuracy: 0.9190 - val_loss: 0.8631 - val_accuracy: 0.7594
# Epoch 230/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2238 - accuracy: 0.9208 - val_loss: 0.7541 - val_accuracy: 0.7896
# Epoch 231/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2350 - accuracy: 0.9169 - val_loss: 0.7278 - val_accuracy: 0.7899
# Epoch 232/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2296 - accuracy: 0.9205 - val_loss: 0.7270 - val_accuracy: 0.7949
# Epoch 233/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2276 - accuracy: 0.9201 - val_loss: 0.7530 - val_accuracy: 0.7939
# Epoch 234/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2310 - accuracy: 0.9193 - val_loss: 0.7523 - val_accuracy: 0.7886
# Epoch 235/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2312 - accuracy: 0.9193 - val_loss: 0.7734 - val_accuracy: 0.7827
# Epoch 236/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2275 - accuracy: 0.9209 - val_loss: 0.7441 - val_accuracy: 0.7944
# Epoch 237/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2301 - accuracy: 0.9206 - val_loss: 0.7842 - val_accuracy: 0.7819
# Epoch 238/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2292 - accuracy: 0.9208 - val_loss: 0.7395 - val_accuracy: 0.7961
# Epoch 239/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2256 - accuracy: 0.9214 - val_loss: 0.7214 - val_accuracy: 0.7935
# Epoch 240/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2269 - accuracy: 0.9206 - val_loss: 0.7309 - val_accuracy: 0.7939
# Epoch 241/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2291 - accuracy: 0.9202 - val_loss: 0.7550 - val_accuracy: 0.7889
# Epoch 242/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2272 - accuracy: 0.9223 - val_loss: 0.8775 - val_accuracy: 0.7706
# Epoch 243/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2307 - accuracy: 0.9194 - val_loss: 0.7884 - val_accuracy: 0.7857
# Epoch 244/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2278 - accuracy: 0.9211 - val_loss: 0.7522 - val_accuracy: 0.7964
# Epoch 245/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2299 - accuracy: 0.9212 - val_loss: 0.7250 - val_accuracy: 0.7985
# Epoch 246/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2285 - accuracy: 0.9205 - val_loss: 0.7207 - val_accuracy: 0.8010
# Epoch 247/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2213 - accuracy: 0.9221 - val_loss: 0.7873 - val_accuracy: 0.7834
# Epoch 248/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2291 - accuracy: 0.9194 - val_loss: 0.8312 - val_accuracy: 0.7817
# Epoch 249/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2226 - accuracy: 0.9228 - val_loss: 0.7259 - val_accuracy: 0.8004
# Epoch 250/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2216 - accuracy: 0.9222 - val_loss: 0.7391 - val_accuracy: 0.7892
# Epoch 251/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2222 - accuracy: 0.9220 - val_loss: 0.7939 - val_accuracy: 0.7802
# Epoch 252/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2309 - accuracy: 0.9196 - val_loss: 0.7435 - val_accuracy: 0.7918
# Epoch 253/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2255 - accuracy: 0.9213 - val_loss: 0.7282 - val_accuracy: 0.7930
# Epoch 254/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2304 - accuracy: 0.9216 - val_loss: 0.7231 - val_accuracy: 0.7964
# Epoch 255/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2244 - accuracy: 0.9227 - val_loss: 0.7578 - val_accuracy: 0.7908
# Epoch 256/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2216 - accuracy: 0.9227 - val_loss: 0.7449 - val_accuracy: 0.7901
# Epoch 257/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2268 - accuracy: 0.9227 - val_loss: 0.7028 - val_accuracy: 0.7999
# Epoch 258/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2185 - accuracy: 0.9249 - val_loss: 0.6946 - val_accuracy: 0.8044
# Epoch 259/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2185 - accuracy: 0.9231 - val_loss: 0.6933 - val_accuracy: 0.8061
# Epoch 260/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2184 - accuracy: 0.9241 - val_loss: 0.7752 - val_accuracy: 0.7818
# Epoch 261/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2243 - accuracy: 0.9227 - val_loss: 0.7990 - val_accuracy: 0.7863
# Epoch 262/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2198 - accuracy: 0.9244 - val_loss: 0.7130 - val_accuracy: 0.7965
# Epoch 263/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2196 - accuracy: 0.9220 - val_loss: 0.7453 - val_accuracy: 0.7994
# Epoch 264/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2193 - accuracy: 0.9227 - val_loss: 0.7676 - val_accuracy: 0.7846
# Epoch 265/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2111 - accuracy: 0.9269 - val_loss: 0.7240 - val_accuracy: 0.7974
# Epoch 266/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2179 - accuracy: 0.9233 - val_loss: 0.7385 - val_accuracy: 0.7973
# Epoch 267/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2181 - accuracy: 0.9253 - val_loss: 0.8306 - val_accuracy: 0.7694
# Epoch 268/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2143 - accuracy: 0.9271 - val_loss: 0.7961 - val_accuracy: 0.7793
# Epoch 269/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2169 - accuracy: 0.9256 - val_loss: 0.7058 - val_accuracy: 0.7994
# Epoch 270/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2186 - accuracy: 0.9247 - val_loss: 0.7497 - val_accuracy: 0.7945
# Epoch 271/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2248 - accuracy: 0.9216 - val_loss: 0.7896 - val_accuracy: 0.7879
# Epoch 272/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2163 - accuracy: 0.9259 - val_loss: 0.7498 - val_accuracy: 0.7946
# Epoch 273/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2161 - accuracy: 0.9247 - val_loss: 0.7044 - val_accuracy: 0.7992
# Epoch 274/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2137 - accuracy: 0.9255 - val_loss: 0.8486 - val_accuracy: 0.7768
# Epoch 275/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2212 - accuracy: 0.9227 - val_loss: 0.7153 - val_accuracy: 0.8016
# Epoch 276/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2134 - accuracy: 0.9257 - val_loss: 0.7714 - val_accuracy: 0.7992
# Epoch 277/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2161 - accuracy: 0.9253 - val_loss: 0.9532 - val_accuracy: 0.7577
# Epoch 278/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2207 - accuracy: 0.9226 - val_loss: 0.7629 - val_accuracy: 0.7889
# Epoch 279/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2092 - accuracy: 0.9283 - val_loss: 0.7707 - val_accuracy: 0.7912
# Epoch 280/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2120 - accuracy: 0.9262 - val_loss: 0.7746 - val_accuracy: 0.7947
# Epoch 281/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2117 - accuracy: 0.9268 - val_loss: 0.7886 - val_accuracy: 0.7925
# Epoch 282/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2194 - accuracy: 0.9247 - val_loss: 0.9963 - val_accuracy: 0.7443
# Epoch 283/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2154 - accuracy: 0.9233 - val_loss: 0.7342 - val_accuracy: 0.7934
# Epoch 284/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2094 - accuracy: 0.9279 - val_loss: 0.7619 - val_accuracy: 0.7853
# Epoch 285/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2061 - accuracy: 0.9296 - val_loss: 0.7528 - val_accuracy: 0.7959
# Epoch 286/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2127 - accuracy: 0.9260 - val_loss: 0.7251 - val_accuracy: 0.7955
# Epoch 287/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2104 - accuracy: 0.9267 - val_loss: 0.7275 - val_accuracy: 0.7934
# Epoch 288/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2105 - accuracy: 0.9259 - val_loss: 0.8027 - val_accuracy: 0.7795
# Epoch 289/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2156 - accuracy: 0.9251 - val_loss: 0.8472 - val_accuracy: 0.7661
# Epoch 290/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2049 - accuracy: 0.9277 - val_loss: 0.7803 - val_accuracy: 0.7898
# Epoch 291/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2134 - accuracy: 0.9270 - val_loss: 0.8098 - val_accuracy: 0.7758
# Epoch 292/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2096 - accuracy: 0.9283 - val_loss: 0.7840 - val_accuracy: 0.7884
# Epoch 293/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2122 - accuracy: 0.9263 - val_loss: 0.7174 - val_accuracy: 0.8023
# Epoch 294/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2130 - accuracy: 0.9274 - val_loss: 0.7621 - val_accuracy: 0.7918
# Epoch 295/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2139 - accuracy: 0.9255 - val_loss: 0.8369 - val_accuracy: 0.7760
# Epoch 296/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2133 - accuracy: 0.9249 - val_loss: 0.8355 - val_accuracy: 0.7816
# Epoch 297/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2076 - accuracy: 0.9283 - val_loss: 0.7637 - val_accuracy: 0.7912
# Epoch 298/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2070 - accuracy: 0.9283 - val_loss: 0.7646 - val_accuracy: 0.7957
# Epoch 299/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2071 - accuracy: 0.9291 - val_loss: 0.7812 - val_accuracy: 0.7922
# Epoch 300/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2127 - accuracy: 0.9266 - val_loss: 0.7610 - val_accuracy: 0.7881
# Epoch 301/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2113 - accuracy: 0.9276 - val_loss: 0.7580 - val_accuracy: 0.7903
# Epoch 302/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2075 - accuracy: 0.9281 - val_loss: 0.7694 - val_accuracy: 0.7865
# Epoch 303/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2156 - accuracy: 0.9250 - val_loss: 0.7307 - val_accuracy: 0.7963
# Epoch 304/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2135 - accuracy: 0.9270 - val_loss: 0.7792 - val_accuracy: 0.7833
# Epoch 305/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2047 - accuracy: 0.9291 - val_loss: 0.7766 - val_accuracy: 0.7830
# Epoch 306/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2055 - accuracy: 0.9286 - val_loss: 0.8415 - val_accuracy: 0.7755
# Epoch 307/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2049 - accuracy: 0.9287 - val_loss: 0.7303 - val_accuracy: 0.7937
# Epoch 308/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2101 - accuracy: 0.9289 - val_loss: 0.9013 - val_accuracy: 0.7591
# Epoch 309/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2051 - accuracy: 0.9284 - val_loss: 0.7616 - val_accuracy: 0.7938
# Epoch 310/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2062 - accuracy: 0.9281 - val_loss: 0.7239 - val_accuracy: 0.8012
# Epoch 311/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2058 - accuracy: 0.9279 - val_loss: 0.7532 - val_accuracy: 0.7980
# Epoch 312/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2067 - accuracy: 0.9290 - val_loss: 0.7988 - val_accuracy: 0.7820
# Epoch 313/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1997 - accuracy: 0.9315 - val_loss: 0.7367 - val_accuracy: 0.8018
# Epoch 314/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2021 - accuracy: 0.9302 - val_loss: 0.7973 - val_accuracy: 0.7836
# Epoch 315/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2052 - accuracy: 0.9284 - val_loss: 0.9429 - val_accuracy: 0.7567
# Epoch 316/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2054 - accuracy: 0.9291 - val_loss: 0.7361 - val_accuracy: 0.8037
# Epoch 317/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1996 - accuracy: 0.9321 - val_loss: 0.7746 - val_accuracy: 0.7878
# Epoch 318/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2071 - accuracy: 0.9280 - val_loss: 0.9113 - val_accuracy: 0.7597
# Epoch 319/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2068 - accuracy: 0.9288 - val_loss: 0.7665 - val_accuracy: 0.7868
# Epoch 320/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2065 - accuracy: 0.9283 - val_loss: 0.7205 - val_accuracy: 0.8041
# Epoch 321/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2063 - accuracy: 0.9294 - val_loss: 0.7482 - val_accuracy: 0.7960
# Epoch 322/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2044 - accuracy: 0.9291 - val_loss: 0.7782 - val_accuracy: 0.7882
# Epoch 323/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2008 - accuracy: 0.9302 - val_loss: 0.7525 - val_accuracy: 0.7996
# Epoch 324/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2072 - accuracy: 0.9281 - val_loss: 0.8457 - val_accuracy: 0.7773
# Epoch 325/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2047 - accuracy: 0.9294 - val_loss: 0.8016 - val_accuracy: 0.7890
# Epoch 326/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2028 - accuracy: 0.9308 - val_loss: 0.7983 - val_accuracy: 0.7840
# Epoch 327/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1985 - accuracy: 0.9308 - val_loss: 0.7002 - val_accuracy: 0.8063
# Epoch 328/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2034 - accuracy: 0.9292 - val_loss: 0.8082 - val_accuracy: 0.7883
# Epoch 329/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1994 - accuracy: 0.9302 - val_loss: 0.7118 - val_accuracy: 0.8061
# Epoch 330/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1910 - accuracy: 0.9330 - val_loss: 0.7245 - val_accuracy: 0.7980
# Epoch 331/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2043 - accuracy: 0.9284 - val_loss: 0.7534 - val_accuracy: 0.7894
# Epoch 332/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1956 - accuracy: 0.9331 - val_loss: 0.7283 - val_accuracy: 0.8014
# Epoch 333/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1999 - accuracy: 0.9317 - val_loss: 0.8605 - val_accuracy: 0.7675
# Epoch 334/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1980 - accuracy: 0.9309 - val_loss: 0.7477 - val_accuracy: 0.7989
# Epoch 335/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1932 - accuracy: 0.9329 - val_loss: 0.8188 - val_accuracy: 0.7762
# Epoch 336/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2016 - accuracy: 0.9310 - val_loss: 0.7737 - val_accuracy: 0.7899
# Epoch 337/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1988 - accuracy: 0.9312 - val_loss: 0.7648 - val_accuracy: 0.7942
# Epoch 338/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1950 - accuracy: 0.9324 - val_loss: 0.8090 - val_accuracy: 0.7841
# Epoch 339/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2002 - accuracy: 0.9319 - val_loss: 0.7150 - val_accuracy: 0.8059
# Epoch 340/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1966 - accuracy: 0.9319 - val_loss: 0.7854 - val_accuracy: 0.7853
# Epoch 341/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1943 - accuracy: 0.9340 - val_loss: 0.8095 - val_accuracy: 0.7717
# Epoch 342/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1974 - accuracy: 0.9316 - val_loss: 0.7510 - val_accuracy: 0.7965
# Epoch 343/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1973 - accuracy: 0.9322 - val_loss: 0.8694 - val_accuracy: 0.7757
# Epoch 344/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1983 - accuracy: 0.9315 - val_loss: 0.7486 - val_accuracy: 0.7938
# Epoch 345/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1999 - accuracy: 0.9308 - val_loss: 0.7848 - val_accuracy: 0.7971
# Epoch 346/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1996 - accuracy: 0.9297 - val_loss: 0.7890 - val_accuracy: 0.7832
# Epoch 347/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1966 - accuracy: 0.9320 - val_loss: 0.7328 - val_accuracy: 0.7990
# Epoch 348/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1959 - accuracy: 0.9325 - val_loss: 0.7952 - val_accuracy: 0.7833
# Epoch 349/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1997 - accuracy: 0.9304 - val_loss: 0.7631 - val_accuracy: 0.7989
# Epoch 350/350
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1945 - accuracy: 0.9319 - val_loss: 0.7709 - val_accuracy: 0.7913

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

# acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
# acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
# acc_ax.set_ylabel('accuracy')
# acc_ax.legend(loc='upper left')

plt.show()

# %%
model.evaluate(X_test,test_idx) # acc: 0.7925
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7595 - accuracy: 0.7925
# [0.7595034837722778, 0.7925000190734863]

# %% [markdown]
# # 추론

# %%
pred_proba = model.predict(X_test) 

pred_class = []

for i in pred_proba:
    pred = np.argmax(i)
    pred_class.append(pred)
    
pred_class = le.inverse_transform(pred_class)
pred_class[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3cbb165ba563> in <module>()
#       7     pred_class.append(pred)
#       8
# ----> 9 pred_class = le.inverse_transform(pred_class)
#      10 pred_class[0:5]
#
# NameError: name 'le' is not defined

# %% [markdown]
# # Dacon 대회 제출

# %%
import pandas as pd

sample_submission = pd.read_csv("./data/sample_submission.csv")

sample_submission.target = pred_class
sample_submission.to_csv("submit.csv",index=False)

# %%
sample_submission.head()
# Out:
#          id    target
# 0  0000.jpg     horse
# 1  0001.jpg      bird
# 2  0002.jpg  airplane
# 3  0003.jpg     horse
# 4  0004.jpg  airplane

# %% [markdown]
# 이렇게 생성된 submission.csv 파일을 데이콘 대회 페이지에 업로드 & 제출하여 결과를 확인하세요.
#
# 축하합니다! 자연어 처리를 완료하셨습니다!
# 이미지 처리의 첫걸음을 떼신 것을 축하드립니다.
#
# 앞으로도 데이콘과 함께 즐겁게 데이터 분석 능력을 키워가시면 좋겠습니다.
#
# 감사합니다.
