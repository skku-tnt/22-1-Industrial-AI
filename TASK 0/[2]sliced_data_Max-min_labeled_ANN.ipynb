# %% [markdown]
# # 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn           as sb
import scipy.stats       as sp

# %%
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(777)

# %% [markdown]
# # 데이터 불러오기

# %%
for i in range (100):
    temp_data = pd.read_csv('C:/Users/dldpf/[1]blow_form/sidewall thickness data/dp%d-blow-thick-sidewallcut.csv'%(i+1), sep=',')
    s = "thickness_dp%d = temp_data"%(i+1)
    exec(s)

# %% [markdown]
# ## 데이터 확인

# %%
for i in range (100):
    s = "plt.plot(thickness_dp%d.iloc[:,1],thickness_dp%d.iloc[:,2])"%(i+1,i+1)
    exec(s)
    plt.xlabel("Curve Length on Polyline")
    plt.ylabel("thickness")
    plt.xlim(0,0.3)
    plt.ylim(0,0.0015)
    plt.title("dp%d"%(i+1),fontsize = 16)
#     plt.savefig("C:/Users/SDML/Desktop/blow thickness plot/dp%d_thickness plot.jpg"%(i+1))
    plt.show()
    plt.clf()

# %%
np.concatenate()

for i in range(100):
thickness_dp1.iloc[]
# Out:
#     Unnamed: 0  Curve Length on Polyline 1 [ m ]  THICKNESS [ m ]
# 0            9                          0.018458         0.000639
# 1           10                          0.020766         0.000563
# 2           11                          0.023228         0.000525
# 3           12                          0.025537         0.000469
# 4           13                          0.028286         0.000401
# 5           14                          0.031332         0.000353
# 6           15                          0.034518         0.000308
# 7           16                          0.038071         0.000259
# 8           17                          0.042211         0.000210
# 9           18                          0.046897         0.000173
# 10          19                          0.052392         0.000153
# 11          20                          0.057826         0.000139
# 12          21                          0.063912         0.000125
# ...

# %%
for i in range (100):
    a = thickness_dp
    s = "a = len(thickness_dp%d.iloc[:,1])"%(i+1)
    exec(s)
    
    print(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9b5ad584a5f8> in <module>
#       1 for i in range (100):
# ----> 2     a = thickness_dp
#       3     s = "a = len(thickness_dp%d.iloc[:,1])"%(i+1)
#       4     exec(s)
#       5
#
# NameError: name 'thickness_dp' is not defined
